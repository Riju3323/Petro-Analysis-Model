# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt #plots

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/spe-oil-dataset/Production_Data.csv
# /kaggle/input/spe-oil-dataset/Well_Data.csv
# /kaggle/input/spe-oil-dataset/Deviation_Survey.csv

# %%
wd = pd.read_csv("../input/spe-oil-dataset/Well_Data.csv")
prd = pd.read_csv("../input/spe-oil-dataset/Production_Data.csv")
ds = pd.read_csv("../input/spe-oil-dataset/Deviation_Survey.csv")

# %%
prd.shape
# Out:
# (60967, 13)

# %%
ds.head()
# Out:
#     Lease  Measured Depth (ft)  TVD (ft)
# 0  OSPREY                  0.0       0.0
# 1  OSPREY                 95.1      95.1
# 2  OSPREY                153.6     153.6
# 3  OSPREY                214.8     214.8
# 4  OSPREY                273.1     273.1

# %%
wd.head()
# Out:
#                                Lease      OSPREY      FALCON        HAWK  \
# 0                        Well Number           1           2           3
# 1                              State          TX          TX          TX
# 2                Formation/Reservoir  EAGLE FORD  EAGLE FORD  EAGLE FORD
# 3   Initial Pressure Estimate (psi)         5400        5700        5650
# 4     Reservoir Temperature (deg F)          225         225         225
#
#         EAGLE        KITE       SWIFT     SPARROW        LARK    CARDINAL  \
# 0           4           5           6           7           8           9
# 1          TX          TX          TX          TX          TX          TX
# 2  EAGLE FORD  EAGLE FORD  EAGLE FORD  EAGLE FORD  EAGLE FORD  EAGLE FORD
# 3        5000        5000        5164        5164        5700        5900
# 4         235         238         225         225         228         228
#
#    ...                OWL              FINCH              ROBIN  \
# 0  ...                 40                 41                 42
# 1  ...                 PA                 PA                 PA
# 2  ...  MARCELLUS - UPPER  MARCELLUS - UPPER  MARCELLUS - UPPER
# 3  ...               2200               4300               4100
# 4  ...                136                133                133
#
#             BLUEBIRD             CANARY            SEAGULL        HUMMINGBIRD  \
# 0                 43                 44                 45                 46
# 1                 PA                 PA                 PA                 PA
# 2  MARCELLUS - UPPER  MARCELLUS - UPPER  MARCELLUS - UPPER  MARCELLUS - UPPER
# 3               4200               4300               4400               4000
# 4                125                133                136                136
#
#              PHOENIX             TOUCAN              GOOSE
# 0                 47                 48                 49
# 1                 PA                 PA                 PA
# 2  MARCELLUS - UPPER  MARCELLUS - UPPER  MARCELLUS - UPPER
# 3               4450               3900               5200
# 4                137                137                134
#
# [5 rows x 54 columns]

# %%
wd2 = wd.copy()
wd2.head()
# Out:
#                                Lease      OSPREY      FALCON        HAWK  \
# 0                        Well Number           1           2           3
# 1                              State          TX          TX          TX
# 2                Formation/Reservoir  EAGLE FORD  EAGLE FORD  EAGLE FORD
# 3   Initial Pressure Estimate (psi)         5400        5700        5650
# 4     Reservoir Temperature (deg F)          225         225         225
#
#         EAGLE        KITE       SWIFT     SPARROW        LARK    CARDINAL  \
# 0           4           5           6           7           8           9
# 1          TX          TX          TX          TX          TX          TX
# 2  EAGLE FORD  EAGLE FORD  EAGLE FORD  EAGLE FORD  EAGLE FORD  EAGLE FORD
# 3        5000        5000        5164        5164        5700        5900
# 4         235         238         225         225         228         228
#
#    ...                OWL              FINCH              ROBIN  \
# 0  ...                 40                 41                 42
# 1  ...                 PA                 PA                 PA
# 2  ...  MARCELLUS - UPPER  MARCELLUS - UPPER  MARCELLUS - UPPER
# 3  ...               2200               4300               4100
# 4  ...                136                133                133
#
#             BLUEBIRD             CANARY            SEAGULL        HUMMINGBIRD  \
# 0                 43                 44                 45                 46
# 1                 PA                 PA                 PA                 PA
# 2  MARCELLUS - UPPER  MARCELLUS - UPPER  MARCELLUS - UPPER  MARCELLUS - UPPER
# 3               4200               4300               4400               4000
# 4                125                133                136                136
#
#              PHOENIX             TOUCAN              GOOSE
# 0                 47                 48                 49
# 1                 PA                 PA                 PA
# 2  MARCELLUS - UPPER  MARCELLUS - UPPER  MARCELLUS - UPPER
# 3               4450               3900               5200
# 4                137                137                134
#
# [5 rows x 54 columns]

# %%
wd2_transposed = wd2.transpose()

# %%
wd2_transposed.head()
# Out:
#                  0      1                    2   \
# Lease   Well Number  State  Formation/Reservoir
# OSPREY            1     TX           EAGLE FORD
# FALCON            2     TX           EAGLE FORD
# HAWK              3     TX           EAGLE FORD
# EAGLE             4     TX           EAGLE FORD
#
#                                        3                                4   \
# Lease    Initial Pressure Estimate (psi)    Reservoir Temperature (deg F)
# OSPREY                               5400                              225
# FALCON                               5700                              225
# HAWK                                 5650                              225
# EAGLE                                5000                              235
#
#                     5                         6         7   \
# Lease    Net Pay (ft)    Wellbore Diameter (ft)   Porosity
# OSPREY              78                       0.7     6.30%
# FALCON              66                       0.7     6.30%
# HAWK                67                       0.7     6.30%
# EAGLE               74                       0.7     6.30%
#
#                         8                 9   ...                         84  \
# Lease    Water Saturation    Oil Saturation   ...  Pressure Loss Correlation
# OSPREY              26.00%            74.00%  ...              Beggs & Brill
# FALCON              27.00%            73.00%  ...                        NaN
# HAWK                27.10%            72.90%  ...                        NaN
# EAGLE               27.00%            73.00%  ...                        NaN
#
#                       85                86                   87  \
# Lease    Tubing ID (in)    Tubing OD (in)    Tubing Depth (ft)
# OSPREY             2.441             2.875                 6764
# FALCON               NaN               NaN                  NaN
# HAWK                 NaN               NaN                  NaN
# EAGLE                NaN               NaN                  NaN
#
#                         88                       89                  90  \
# Lease    Casing ID 1 (in)    Casing Footage 1 (ft)    Casing ID 2 (in)
# OSPREY                4.67                     6941               2.992
# FALCON                 NaN                      NaN                 NaN
# HAWK                   NaN                      NaN                 NaN
# EAGLE                  NaN                      NaN                 NaN
#
#                              91                   92  \
# Lease    Casing Footage 2 (ft)    Casing Depth (ft)
# OSPREY                     6307                13248
# FALCON                      NaN                  NaN
# HAWK                        NaN                  NaN
# EAGLE                       NaN                  NaN
#
#                                                        93
# Lease                                        Description
# OSPREY   Well began producing and was later recomplete...
# FALCON   Interior well on a 3-well pad that was shut-i...
# HAWK     Exterior well on a 3-well pad that was shut-i...
# EAGLE    Single unbounded well with modern completion ...
#
# [5 rows x 94 columns]

# %%
wd2_transposed.reset_index(inplace=True)
wd2_transposed.head()
# Out:
#     index            0      1                    2  \
# 0   Lease  Well Number  State  Formation/Reservoir
# 1  OSPREY            1     TX           EAGLE FORD
# 2  FALCON            2     TX           EAGLE FORD
# 3    HAWK            3     TX           EAGLE FORD
# 4   EAGLE            4     TX           EAGLE FORD
#
#                                    3                                4  \
# 0   Initial Pressure Estimate (psi)    Reservoir Temperature (deg F)
# 1                               5400                              225
# 2                               5700                              225
# 3                               5650                              225
# 4                               5000                              235
#
#                 5                         6         7                   8  \
# 0   Net Pay (ft)    Wellbore Diameter (ft)   Porosity   Water Saturation
# 1              78                       0.7     6.30%              26.00%
# 2              66                       0.7     6.30%              27.00%
# 3              67                       0.7     6.30%              27.10%
# 4              74                       0.7     6.30%              27.00%
#
#    ...                         84                85                86  \
# 0  ...  Pressure Loss Correlation   Tubing ID (in)    Tubing OD (in)
# 1  ...              Beggs & Brill             2.441             2.875
# 2  ...                        NaN               NaN               NaN
# 3  ...                        NaN               NaN               NaN
# 4  ...                        NaN               NaN               NaN
#
#                     87                  88                       89  \
# 0   Tubing Depth (ft)    Casing ID 1 (in)    Casing Footage 1 (ft)
# 1                 6764                4.67                     6941
# 2                  NaN                 NaN                      NaN
# 3                  NaN                 NaN                      NaN
# 4                  NaN                 NaN                      NaN
#
#                    90                       91                   92  \
# 0   Casing ID 2 (in)    Casing Footage 2 (ft)    Casing Depth (ft)
# 1               2.992                     6307                13248
# 2                 NaN                      NaN                  NaN
# 3                 NaN                      NaN                  NaN
# 4                 NaN                      NaN                  NaN
#
#                                                   93
# 0                                       Description
# 1   Well began producing and was later recomplete...
# 2   Interior well on a 3-well pad that was shut-i...
# 3   Exterior well on a 3-well pad that was shut-i...
# 4   Single unbounded well with modern completion ...
#
# [5 rows x 95 columns]

# %%
wd2_transposed.rename(columns={'index': 'Lease'}, inplace=True)
wd2.shape
# Out:
# (94, 54)

# %%
tempp = pd.merge(wd2_transposed, prd, on='Lease')

# %%
tempp.head()
# Out:
#     Lease  0   1           2     3    4   5    6      7       8  ...  \
# 0  OSPREY  1  TX  EAGLE FORD  5400  225  78  0.7  6.30%  26.00%  ...
# 1  OSPREY  1  TX  EAGLE FORD  5400  225  78  0.7  6.30%  26.00%  ...
# 2  OSPREY  1  TX  EAGLE FORD  5400  225  78  0.7  6.30%  26.00%  ...
# 3  OSPREY  1  TX  EAGLE FORD  5400  225  78  0.7  6.30%  26.00%  ...
# 4  OSPREY  1  TX  EAGLE FORD  5400  225  78  0.7  6.30%  26.00%  ...
#
#   Gas Volume (MMscf) Oil Volume (stb) Water Volume  (stb)  \
# 0              0.145           504.39               718.0
# 1              0.186           564.76               922.0
# 2              0.231           653.51               753.0
# 3              0.268           740.71               700.0
# 4              0.261           678.06               530.0
#
#   Gas Lift Inj Volume  (MMscf) Casing Pressure  (psi(a))  \
# 0                          NaN               2064.695943
# 1                          NaN               1989.695943
# 2                          NaN               1864.695943
# 3                          NaN               1814.695943
# 4                          NaN               1714.695943
#
#   Tubing Pressure  (psi(a)) Active Pressure  (psi(a)) Line Pressure  (psi(a))  \
# 0                 14.695943               2064.695943               14.695943
# 1                 14.695943               1989.695943               14.695943
# 2                 14.695943               1864.695943               14.695943
# 3                 14.695943               1814.695943               14.695943
# 4                 14.695943               1714.695943               14.695943
#
#   Pressure Source  Calculated Sandface Pressure  (psi(a))
# 0  Casing Pressure                            5050.159793
# 1  Casing Pressure                            5009.599839
# 2  Casing Pressure                            4795.991972
# 3  Casing Pressure                            4696.626023
# 4  Casing Pressure                            4546.990059
#
# [5 rows x 107 columns]

# %%
tempp.shape
# Out:
# (60967, 107)
